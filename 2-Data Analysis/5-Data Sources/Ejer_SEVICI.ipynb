# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];node[amenity=bicycle_rental]
(37.3582,-7,37.4428,-5.8599);out;
"""
response = requests.get(overpass_url,
                        params={'data': overpass_query})
data = response.json()

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.59 e21c39fe',
#  'osm3s': {'timestamp_osm_base': '2022-10-28T11:58:54Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 308961227,
#    'lat': 37.3978439,
#    'lon': -5.9984791,
#    'tags': {'amenity': 'bicycle_rental',
#     'capacity': '20',
#     'name': '039 Plaza San Antonio de Padua',
#     'network': 'Sevici',
#     'operator': 'JCDecaux',
#     'ref': '39',
#     'source': 'JCDecaux',
#     'source:url': 'https://developer.jcdecaux.com/#/opendata'}},
#   {'type': 'node',
#    'id': 308965974,
#    'lat': 37.3975405,
#    'lon': -5.9966186,
#    'tags': {'amenity': 'bicycle_rental',
#     'capacity': '17',
#     'name': '050 Calle de Hernán Cortés',
#     'network': 'Sevici',
#     'operator': 'JCDecaux',
#     'ref': '50',
#     'source': 'JCDecaux',
# ...

# %%
name = []
capacity = []
ID = []
lat = []
lon = []
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];node[amenity=bicycle_rental]
(37.3582,-7,37.4428,-5.8599);out;
"""
response = requests.get(overpass_url,
                        params={'data': overpass_query})
data = response.json()
dic_general = data['elements']
try:
    for i in dic_general:
        ID.append(i['id'])
        lat.append(i["lat"])
        lon.append(i['lon'])
        name.append(i.get('tags').get('name'))
        capacity.append(i.get('tags').get('capacity'))
except:
    None
df = pd.DataFrame({'lat':lat,
                   'lon':lon,
                   'capacity':capacity,
                   'name':name})

# %%
import pandas as pd
import numpy as np
import requests
import json
name = []
capacity = []
ID = []
lat = []
lon = []
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];node[amenity=bicycle_rental]
(37.3582,-7,37.4428,-5.8599);out;
"""
response = requests.get(overpass_url,
                        params={'data': overpass_query})
data = response.json()
dic_general = data['elements']
try:
    for i in dic_general:
        ID.append(i['id'])
        lat.append(i["lat"])
        lon.append(i['lon'])
        name.append(i.get('tags').get('name'))
        capacity.append(i.get('tags').get('capacity'))
except:
    None
df = pd.DataFrame({'lat':lat,
                   'lon':lon,
                   'capacity':capacity,
                   'name':name})

# %%
df
# Out:
#            lat       lon capacity                            name
# 0    37.397844 -5.998479       20  039 Plaza San Antonio de Padua
# 1    37.397540 -5.996619       17      050 Calle de Hernán Cortés
# 2    37.396898 -5.993847       20         049 Alameda de Hercúles
# 3    37.400790 -5.993800       20         035 Alameda de Hercúles
# 4    37.399488 -5.990986       15  041 Plaza Calderón de la Barca
# ..         ...       ...      ...                             ...
# 250  37.400768 -5.993229     None                            None
# 251  37.413144 -5.985366     None                            None
# 252  37.388906 -5.995631     None                            None
# 253  37.388867 -5.996135     None                            None
# 254  37.381591 -5.989233     None                            None
#
# [255 rows x 4 columns]

# %%
df=df.dropna()
df['name']= df['name'].apply(lambda x : x[4:])
df
# Out:
# c:\Users\Alberto\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            lat       lon capacity                          name
# 0    37.397844 -5.998479       20    Plaza San Antonio de Padua
# 1    37.397540 -5.996619       17        Calle de Hernán Cortés
# 2    37.396898 -5.993847       20           Alameda de Hercúles
# 3    37.400790 -5.993800       20           Alameda de Hercúles
# 4    37.399488 -5.990986       15    Plaza Calderón de la Barca
# ..         ...       ...      ...                           ...
# 243  37.383769 -5.908922       20             Torres Albarracin
# 244  37.367318 -5.954117       30                 Ocho de Marzo
# ...

# %%
import random
df['distrito']=1
df['distrito']= df['distrito'].apply(lambda x : random.randint(1,4))
df
# Out:
#            lat       lon capacity                            name  distrito
# 0    37.397844 -5.998479       20  039 Plaza San Antonio de Padua         1
# 1    37.397540 -5.996619       17      050 Calle de Hernán Cortés         1
# 2    37.396898 -5.993847       20         049 Alameda de Hercúles         1
# 3    37.400790 -5.993800       20         035 Alameda de Hercúles         1
# 4    37.399488 -5.990986       15  041 Plaza Calderón de la Barca         1
# ..         ...       ...      ...                             ...       ...
# 250  37.400768 -5.993229     None                            None         3
# 251  37.413144 -5.985366     None                            None         2
# 252  37.388906 -5.995631     None                            None         3
# 253  37.388867 -5.996135     None                            None         1
# 254  37.381591 -5.989233     None                            None         2
#
# [255 rows x 5 columns]

# %%
df_bicis.to_csv('bicis.csv')

# %%
total=df_bicis['capacity'].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3916\1061617292.py in <module>
# ----> 1 total=df_bicis['capacity'].sum()
#
# c:\Users\Alberto\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10707         ):
#   10708             return NDFrame.sum(
# > 10709                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   10710             )
#   10711
#
# c:\Users\Alberto\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10445     ):
#   10446         return self._min_count_stat_function(
# > 10447             "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10448         )
#   10449
#
# ...

# %%
elif menu_lateral == "Datos":
    st.title(" Datos de Sevici")
    st.metric('Distrito', df['capacity'].sum(), delta=20, delta_color="normal", help=None)
    df
elif menu_lateral == "Visualizacion":
    st.title("Mapa de Bicis")
    st.map(data=df, zoom=None, use_container_width=True)
