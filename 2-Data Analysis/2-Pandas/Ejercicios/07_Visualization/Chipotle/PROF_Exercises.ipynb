# %% [markdown]
# # Visualizing Chipotle's Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. Create a histogram of the top 5 items bought

# %%
top_sales = df.groupby('item_name')['quantity'].sum().sort_values(ascending=False).head()
top_sales.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='item_name'>

# %%
df.groupby('item_name')['quantity'].count().sort_values(ascending=False)
# Out:
# item_name
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chicken Salad Bowl                       110
# Chips and Fresh Tomato Salsa             110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
top_sales = df.groupby('item_name')['quantity'].count().sort_values(ascending=False)#.head()
top_sales.plot(kind="bar", figsize=(30, 10))
plt.xticks(fontsize=18);

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
ax.hist(df['item_name'], bins=50)
# Out:
# (array([110.,  20.,  27.,  31., 726., 101., 368.,  55., 479.,  47., 115.,
#         553., 104.,  91.,  59.,  68., 162.,  43.,  66., 211., 110., 211.,
#          25.,  95.,  85.,  35.,  48.,  11.,  18.,  18.,  22.,  40.,   9.,
#         301.,  29.,  54.,  20.,   2.,   6.,   2.,   7.,   4.,   1.,   7.,
#           6.,  10.,   2.,   1.,   6.,   1.]),
#  array([ 0.  ,  0.98,  1.96,  2.94,  3.92,  4.9 ,  5.88,  6.86,  7.84,
#          8.82,  9.8 , 10.78, 11.76, 12.74, 13.72, 14.7 , 15.68, 16.66,
#         17.64, 18.62, 19.6 , 20.58, 21.56, 22.54, 23.52, 24.5 , 25.48,
#         26.46, 27.44, 28.42, 29.4 , 30.38, 31.36, 32.34, 33.32, 34.3 ,
#         35.28, 36.26, 37.24, 38.22, 39.2 , 40.18, 41.16, 42.14, 43.12,
#         44.1 , 45.08, 46.06, 47.04, 48.02, 49.  ]),
#  <BarContainer object of 50 artists>)

# %%
fig, ax = plt.subplots(figsize=(30, 10))
ax.hist(df['item_name'], bins=50)
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
ax.tick_params(axis='both', labelsize=18, rotation=90);

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Step 6. Create a scatterplot with the number of items orderered per order price
# #### Hint: Price should be in the X-axis and Items ordered in the Y-axis

# %%
df['item_price_num'] = df['item_price'].str.replace("$", "", regex=False).astype(float)

# %%
num_items_order = df.groupby('order_id')[['quantity']].sum()

def fun_aux(x):
    x['total_amount'] = (x['quantity'] * x['item_price_num']).sum()
    return x
price_per_order = df.groupby('order_id')[['order_id','quantity', 'item_price_num']].apply(fun_aux)

# %%
price_per_order[['order_id', 'total_amount']].drop_duplicates()
# Out:
#       order_id  total_amount
# 0            1         11.56
# 4            2         33.96
# 5            3         12.67
# 7            4         21.00
# 9            5         13.70
# ...        ...           ...
# 4610      1830         23.00
# 4612      1831         12.90
# 4615      1832         13.20
# 4617      1833         23.50
# 4619      1834         28.75
#
# [1834 rows x 2 columns]

# %%
df_plot = pd.merge(num_items_order, price_per_order[['order_id', 'total_amount']].drop_duplicates(), on='order_id')

# %%
df_plot.dtypes
# Out:
# order_id          int64
# quantity          int64
# total_amount    float64
# dtype: object

# %%
df_plot.plot(x='total_amount', y='quantity', kind='scatter')
# Out:
# <AxesSubplot:xlabel='total_amount', ylabel='quantity'>

# %%
df[df['order_id'].isin([1443])]
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3599      1443         7                 Bottled Water
# 3600      1443         1             6 Pack Soft Drink
# 3601      1443         3                Veggie Burrito
# 3602      1443         4               Chicken Burrito
# 3603      1443         3                 Steak Burrito
# 3604      1443         2                 Bottled Water
#
#                                      choice_description item_price  \
# 3598                                                NaN    $44.25
# 3599                                                NaN    $10.50
# 3600                                             [Coke]     $6.49
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $33.75
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $35.00
# 3603  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $27.75
# ...

# %%
df_plot.head()
# Out:
#    order_id  quantity  total_amount
# 0         1         4         11.56
# 1         2         2         33.96
# 2         3         2         12.67
# 3         4         2         21.00
# 4         5         2         13.70

# %%
ls_ids = df_plot.sort_values(by='total_amount', ascending=False).head()['order_id'].unique()
ls_ids
# Out:
# array([1443,  511, 1559, 1660,  926], dtype=int64)

# %%
df_sorted_by_amount = df_plot.sort_values(by='total_amount', ascending=False)
ls_top5_ids = df_sorted_by_amount.head()['order_id'].unique()
df_notbig = df_plot[~df_plot['order_id'].isin(ls_top5_ids)]
df_notbig.plot(x='total_amount', y='quantity', kind='scatter')
# Out:
# <AxesSubplot:xlabel='total_amount', ylabel='quantity'>

# %%
df_notbig.corr()['quantity']
# Out:
# order_id        0.039123
# quantity        1.000000
# total_amount    0.733193
# Name: quantity, dtype: float64

# %% [markdown]
# ### Step 7. BONUS: Create a question and a graph to answer your own question.
