# %%
import pandas as pd
df = pd.read_excel('Sample - Superstore.xlsx')

# %% [markdown]
# ## Parentesis vs corchetes
# 1. **Corchetes** (Selección de filas o columnas):
#     - Listas y tuplas: indexing y slicing
#     - Numpy: index y slicing
#     - Dataframe: inexing y slicing + loc/iloc
# 2. **Paréntesis**: para métodos y funciones.
#     - Si viene de un objeto: es un metodo. objeto.metodo()
#     - Si se ejecuta tal cual, e suna función o una clase.

# %%
# df['Country'] # Series
# df[['Country']] # DF de una columna
# df[['Country', 'City']] # DF de dos columnas

# %%
df.index = list(range(1, len(df)+1)) # Para cambiar el indice
# df.loc[0] # Indice explicito. Da error. Nos cargamos el 0 en el indice
# df.loc[1] # Elemento del indice que se llama 1
# df.iloc[0] # Equivalente al enterior. Acceso por indice implicito.
# df.loc[:, 'Country':'City'] # Slicing de columnas
# df.iloc[0:5, :] # Slicing de filas

# %%
df.info()
# Ver métodos del string de Python
#https://www.w3schools.com/python/python_ref_string.asp
    
# Ver funciones built in de Python
# https://docs.python.org/3/library/functions.html
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9994 entries, 1 to 9994
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   datetime64[ns]
#  2   Ship Date      9994 non-null   datetime64[ns]
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %%
df['Customer Name'].str.replace("s", "$")
# Out:
# 1            Claire Gute
# 2            Claire Gute
# 3        Darrin Van Huff
# 4         Sean O'Donnell
# 5         Sean O'Donnell
#               ...
# 9990    Tom Boeckenhauer
# 9991         Dave Brook$
# 9992         Dave Brook$
# 9993         Dave Brook$
# 9994        Chri$ Corte$
# Name: Customer Name, Length: 9994, dtype: object

# %% [markdown]
# ## Group by
# Cuando queremos calcular une stadistico para cada grupo de una variable categorica

# %%
pd.DataFrame(df.groupby(['City'])['Sales'].mean())
# Out:
#                   Sales
# City
# Aberdeen      25.500000
# Abilene        1.392000
# Akron        129.999333
# Albuquerque  158.582857
# Alexandria   344.973125
# ...                 ...
# Woonsocket    48.887500
# Yonkers      510.511067
# York         163.595600
# Yucaipa       50.800000
# Yuma         210.216250
#
# [531 rows x 1 columns]

# %%
df[['City', 'Segment', 'Sales']]
# Out:
#                  City    Segment     Sales
# 1           Henderson   Consumer  261.9600
# 2           Henderson   Consumer  731.9400
# 3         Los Angeles  Corporate   14.6200
# 4     Fort Lauderdale   Consumer  957.5775
# 5     Fort Lauderdale   Consumer   22.3680
# ...               ...        ...       ...
# 9990            Miami   Consumer   25.2480
# 9991       Costa Mesa   Consumer   91.9600
# 9992       Costa Mesa   Consumer  258.5760
# 9993       Costa Mesa   Consumer   29.6000
# 9994      Westminster   Consumer  243.1600
#
# [9994 rows x 3 columns]

# %%
df.Segment.unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df.groupby(['City', 'Segment'])['Sales'].mean().unstack(level=1, fill_value=0)
# Out:
# Segment        Consumer   Corporate  Home Office
# City
# Aberdeen      25.500000    0.000000     0.000000
# Abilene        1.392000    0.000000     0.000000
# Akron         68.091385  303.645333    11.463000
# Albuquerque   44.949000  239.475500   180.410333
# Alexandria    43.606667  740.690000   134.944286
# ...                 ...         ...          ...
# Woonsocket    52.960000   47.530000     0.000000
# Yonkers      572.405077    0.000000   108.200000
# York           0.000000  163.595600     0.000000
# Yucaipa        0.000000   50.800000     0.000000
# Yuma           0.000000   98.012000   322.420500
#
# [531 rows x 3 columns]

# %%
# Media de ventas
df['Sales'].mean()

# # Media de ventas para cada ciudad
df.groupby('City').mean()['Sales']

# # Media de ventas por segmento y ciudad
df.groupby(['City', 'Segment']).mean()['Sales'].reset_index(0) # 0 o 1
# Out:
# C:\Users\alber\AppData\Local\Temp\ipykernel_54316\2207188824.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City').mean()['Sales']
# C:\Users\alber\AppData\Local\Temp\ipykernel_54316\2207188824.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['City', 'Segment']).mean()['Sales'].reset_index(0) # 0 o 1
#                  City       Sales
# Segment
# Consumer     Aberdeen   25.500000
# Consumer      Abilene    1.392000
# Consumer        Akron   68.091385
# Corporate       Akron  303.645333
# Home Office     Akron   11.463000
# ...               ...         ...
# ...

# %% [markdown]
# ## Filtrar, máscaras

# %%
mask_claire = (df['Customer Name'] == 'Claire Gute')
df[mask_claire]
# Out:
#             Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 1     CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2     CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 5492  CA-2017-164098 2017-01-26 2017-01-27   First Class    CG-12520
# 6878  US-2015-123918 2015-10-15 2015-10-15      Same Day    CG-12520
# 6879  US-2015-123918 2015-10-15 2015-10-15      Same Day    CG-12520
#
#      Customer Name   Segment        Country       City     State  Postal Code  \
# 1      Claire Gute  Consumer  United States  Henderson  Kentucky        42420
# 2      Claire Gute  Consumer  United States  Henderson  Kentucky        42420
# 5492   Claire Gute  Consumer  United States    Houston     Texas        77070
# 6878   Claire Gute  Consumer  United States     Dallas     Texas        75217
# 6879   Claire Gute  Consumer  United States     Dallas     Texas        75217
#
#        Region       Product ID         Category Sub-Category  \
# ...

# %%
# LAS MASCARAS ESTÁN PARA FILTRAR FILAS
# Mascara de todo el DF
df.isnull()

# Mascara por una columna
df['State'] == 'Kentucky'

# Multiples condiciones
mask = (df['State'] == 'Kentucky') & (df['Ship Mode'] == 'Second Class')

# Multiples valores para una columna
ciudades = ['Henderson', 'Florence']
df[df['City'].isin(ciudades)]

# Aplicar una máscara
df[mask]

# Filtrar nulos. No hay en esta columna
df[df['City'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []

# %% [markdown]
# ## Apply
# Cuando hay que modificar valores de una columna

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 3     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
ls = [2, 3, 4, 7]

new_ls = []
for num in ls:
    # if num % 2 == 0:
    #     new_ls.append(num)

    new_ls.append(num) if num%2==0 else None

new_ls
# Out:
# [2, 4]

# %%
df['Category'].apply(lambda x: 'Aquí está' if x == "Furniture" else x)
# Out:
# 1             Aquí está
# 2             Aquí está
# 3       Office Supplies
# 4             Aquí está
# 5       Office Supplies
#              ...
# 9990          Aquí está
# 9991          Aquí está
# 9992         Technology
# 9993    Office Supplies
# 9994    Office Supplies
# Name: Category, Length: 9994, dtype: object

# %%
# Una columna de entrada, una de salida
def mifun(x):
    return x*100000

df['Sales'].apply(mifun)
# Out:
# 1       26196000.0
# 2       73194000.0
# 3        1462000.0
# 4       95757750.0
# 5        2236800.0
#            ...
# 9990     2524800.0
# 9991     9196000.0
# 9992    25857600.0
# 9993     2960000.0
# 9994    24316000.0
# Name: Sales, Length: 9994, dtype: float64

# %%
# Varias columas de entrada, una salida
# def mifun(x, y):
#     return x + ' - ' + y

df.apply(lambda x: x['City'] + " - " + x['State'], axis=1)
# Out:
# 1            Henderson - Kentucky
# 2            Henderson - Kentucky
# 3        Los Angeles - California
# 4       Fort Lauderdale - Florida
# 5       Fort Lauderdale - Florida
#                   ...
# 9990              Miami - Florida
# 9991      Costa Mesa - California
# 9992      Costa Mesa - California
# 9993      Costa Mesa - California
# 9994     Westminster - California
# Length: 9994, dtype: object

# %%
# Una columa de entrada, varias de salida
def mifun(x):
    return pd.Series((x*10, x*1000))

df[['Sales_10', 'Sales_1000']] = df['Sales'].apply(mifun)
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2      Claire Gute   Consumer  United States        Henderson    Kentucky
# 3  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 5   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    ...       Product ID         Category Sub-Category  \
# ...

# %%
# Varias columnas de entrada, varias de salida
def mifun(x):
    return pd.Series((x*10, x*1000))

df[['Sales_10', 'Sales_1000']] = zip(*df['Sales', 'Profit'].apply(mifun, axis=1))
df.head()

# %% [markdown]
# ## Concat, append, merge
# Siempre hay una clave de cruce y unas columnas comunes. Se puede razonas los joins con teoria de conjuntos (bolas y nombres de clientes...)
# 1. **Concat** (mantiene los index originales):
#     - Entre series, concatena los series linealmente
#     - Entre DF: los oncatena verticalmente si coinciden en columnas
#     - pd.concat([x, y], ignore_index=True) para que ignore el indice y ponga un RangeIndex nuevo.
# 2. **Append**: funciona como el concat. Existe por el nombre que tiene. Concatenado vertical.
# 3. **Merge**:
#     - Realiza el join por las columnas comunes entre os dos dataframes
#     - Por defecto es un inner join.
#     - 'left_on' y 'right_on' para especificar las columnas de cruce
#     - 'left_index' y  'right_index' por si se quiere hacer el cruce por indice
#     - Se pueden mezclar en el cruce indice con columna
#     - Outer es en realidad full outer join
# 4. **Join**:
#     - Por defecto, lo hace por indice

# %% [markdown]
# ```Python
# df3 = pd.merge(df1, df2)
# pd.merge(df1, df3, left_on="employee", right_on="name")
# pd.merge(df1a, df2a, left_index=True, right_index=True)
# ```
